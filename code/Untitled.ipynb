# %% [markdown]
# # Форма 101

# %%
import pandas as pd

# %%
form_101 = pd.read_hdf('/Users/roman142001/Documents/diplom/dataframe/form101.h5',key='101')

# %% [markdown]
# Описание всех столбцов данных можно найти в пдф файлах на гитхабе в папке

# %%
form_101
# Out:
#             REGN PLAN  NUM_SC A_P          VR       VV        VITG  \
# DT
# 2007-01-01  2838    В   91404   2      2204.0     53.0      2257.0
# 2007-01-01   435    А   30114   1         0.0  12901.0     12901.0
# 2007-01-01   435    А   30202   1    118193.0      0.0    118193.0
# 2007-01-01   435    А   30204   1     11333.0      0.0     11333.0
# 2007-01-01   435    А   30213   1       272.0      0.0       272.0
# ...          ...  ...     ...  ..         ...      ...         ...
# 2021-12-01  1343    А   50208   1   5979723.0      0.0   5979723.0
# 2021-12-01  1343    А   50207   1   2616695.0      0.0   2616695.0
# 2021-12-01  1343    А   50206   1     63922.0      0.0     63922.0
# 2021-12-01  1343    А   30243   2       631.0      0.0       631.0
# 2021-12-01  2307    А   42502   2  16629000.0      0.0  16629000.0
#
#                    ORA      OVA       OITGA         ORP      OVP       OITGP  \
# DT
# ...
